# %% [markdown]
# # 1. Scrape tweets from @dexpose_io

# %% [markdown]
# **Code reference:** https://github.com/bocchilorenzo/ntscraper

# %%
from ntscraper import Nitter

scraper = Nitter(0)
# Out:
# Testing instances: 100%|███████████████████████████████████████████████████████████████| 77/77 [01:30<00:00,  1.18s/it]

# %%
from dateutil import parser
from io import StringIO
import pandas as pd
import pytz
import time
import datetime

def parse_date_custom(date_str):
    # Assume new data might still use the local time format without explicit timezone
    format_new_data = "%b %d, %Y · %I:%M %p UTC"  # For new data scraped in a different format

    # Directly parse the ISO 8601 format including timezone
    try:
        date_parsed = pd.to_datetime(date_str, errors='coerce')
        if not pd.isna(date_parsed):
            # If the date was parsed successfully, ensure it's in UTC
            return date_parsed.tz_convert(pytz.utc) if date_parsed.tzinfo else date_parsed.tz_localize(pytz.utc)
    except ValueError:
        date_parsed = pd.NaT

    # Try parsing any new data format
    if pd.isna(date_parsed):
        try:
            date_parsed = pd.to_datetime(date_str, format=format_new_data, errors='coerce')
            if not pd.isna(date_parsed):
                # New data format assumed to be in UTC, so localize without conversion
                return date_parsed.tz_localize(pytz.utc)
        except ValueError:
            return pd.NaT

    return date_parsed


def decode(name):
    try:
        with open(f'{name}.csv', 'rb') as file:
            content = file.read().decode('utf-8', errors='replace')
        data_io = StringIO(content)
        df_existing = pd.read_csv(data_io)
        # Apply custom parsing immediately after loading
        df_existing['Date (UTC)'] = df_existing['Date (UTC)'].apply(parse_date_custom)
    except FileNotFoundError:
        df_existing = pd.DataFrame()
    return df_existing

def get_tweets(name, modes, no):
    retry_delay = 0  # Initialize delay
    max_retries = 100  # Set maximum number of retries

    df_existing = decode(name)  # Load and parse existing data
    
    for retry in range(max_retries):
        tweets = scraper.get_tweets(name, mode=modes, number=no)
        if not tweets['tweets']:
            print(f'Retrying in {retry_delay} second{"s" if retry_delay > 1 else ""}...')
            time.sleep(retry_delay)
            retry_delay += 0  # Increment delay for each retry
            continue
        else:
            profile = scraper.get_profile_info(name)
            current_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            print(f'Successfully scraped {no} tweets as at {current_time} from @{name}!')
            if not profile is None: 
                print(f'Profile Info of @{username}\n{"="*40}')
                print(f"Name: {profile['name']}")
                print(f"Bio: {profile['bio']}")
                print(f"Location: {profile['location']}")
                print(f"Website: {profile['website']}")
                print(f"Joined: {profile['joined']}")
            #print(tweets)
            final_tweets = [ 
                [x['date'], x['link'], x['pictures'][0] if x['pictures'] else None, x['text']] 
                for x in tweets['tweets'] 
            ]
            dat = pd.DataFrame(final_tweets, columns=['Date (UTC)', 'URL', 'Image', 'Text'])
            dat['Date (UTC)'] = dat['Date (UTC)'].apply(parse_date_custom)  # Parse new data
            
            # Add a "Scrape Date" column and set it to the current date for the newly scraped data
            dat['Scrape Date'] = pd.to_datetime('today').strftime('%Y-%m-%d %H:%M:%S+00:00')

            # Concatenate existing and newly scraped data
            df_all = pd.concat([df_existing, dat])
            
            # Drop duplicates based on "Date (UTC)" while keeping the first occurrence of non-empty "Scrape Date"
            df_all = df_all.sort_values(by='Scrape Date', ascending=False).drop_duplicates(subset=['Date (UTC)'], keep='last')

            # Sort by "Date (UTC)"
            df_all.sort_values(by='Date (UTC)', ascending=False, inplace=True)
            
            df_all.to_csv(f'{name}.csv', index=False, encoding='utf-8')
            return df_all

    print("Failed to scrape tweets after maximum retries.")
    return pd.DataFrame()

# %%
username = "dexpose_io"

profile = scraper.get_profile_info(username)
tweets = get_tweets(username, 'user', 50)
# Out:
# 01-Jul-24 10:20:11 - No instance specified, using random instance https://nitter.privacydev.net
# 01-Jul-24 10:20:17 - No instance specified, using random instance https://nitter.privacydev.net
# 01-Jul-24 10:20:23 - Current stats for dexpose_io: 20 tweets, 0 threads...
# 01-Jul-24 10:20:27 - Current stats for dexpose_io: 40 tweets, 0 threads...
# 01-Jul-24 10:20:31 - Current stats for dexpose_io: 50 tweets, 0 threads...
# 01-Jul-24 10:20:31 - No instance specified, using random instance https://nitter.privacydev.net
# Successfully scraped 50 tweets as at 2024-07-01 10:20:36 from @dexpose_io!
# Profile Info of @dexpose_io
# ========================================
# Name: DeXpose
# Bio: Finding the needles in the cyber haystack.
# Location:
# Website: http://dexpose.io
# Joined: 11:59 AM - 3 Oct 2022

# %% [markdown]
# # 2. Extract useful information from tweets

# %% [markdown]
# Each tweet from [@dexpose_io](https://twitter.com/dexpose_io) is a cyber threat alert.
#
# We make use of LLM and AI vision to extract details from each tweet.
#
# We will employ the GPT-3.5 Turbo model through Azure OpenAI API to analyze the tweet text, and from which to identify the victimized organization and country.
#
# We will employ **GPT-4 vision model** through Azure OpenAI API to analyze the tweet imgage, and from which to identify the victimized organization and country from.
#
# The reason of employing both techniques together is to provide a second output just in case the first one is incorrect or missing.

# %%
from dotenv import load_dotenv
from langchain_openai import AzureChatOpenAI
import os
import json
import pandas as pd
from PIL import Image
from io import BytesIO
import requests
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from langchain.schema import HumanMessage, SystemMessage

# Load API keys and configurations from .env file as environment variables
load_dotenv() 

# Initialize Azure LLM (GPT-3.5 Turbo) for simple text processing
azure_gpt35turbo = AzureChatOpenAI(
    azure_endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT"),
    api_key=os.environ.get("AZURE_OPENAI_KEY"),
    openai_api_version=os.environ.get("AZURE_OPENAI_VERSION"),
    azure_deployment=os.environ.get("AZURE_OPENAI_DEPLOYMENT_GPT35TURBO"),
    temperature=0
)

# Initialize Azure LLM (GPT-4) for more more complex agentic tasks
azure_gpt4 = AzureChatOpenAI(
    azure_endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT"),
    api_key=os.environ.get("AZURE_OPENAI_KEY"),
    openai_api_version=os.environ.get("AZURE_OPENAI_VERSION"),
    azure_deployment=os.environ.get("AZURE_OPENAI_DEPLOYMENT_GPT4"),
    temperature=0
)

# Initialize Azure LLM (GPT-4o) for more more complex agentic tasks
azure_gpt4o = AzureChatOpenAI(
    azure_endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT_GPT4O"),
    api_key=os.environ.get("AZURE_OPENAI_KEY_GPT4O"),
    openai_api_version=os.environ.get("AZURE_OPENAI_VERSION"),
    azure_deployment=os.environ.get("AZURE_OPENAI_DEPLOYMENT_GPT4O"),
    temperature=0
)

# Initialize Azure GPT4 Vision model for image processing
azure_gpt4vision = AzureChatOpenAI(
    azure_endpoint=os.environ.get("AZURE_OPENAI_VISION_ENDPOINT"),
    api_key=os.environ.get("AZURE_OPENAI_VISION_KEY"),
    openai_api_version=os.environ.get("AZURE_OPENAI_VERSION"),
    azure_deployment=os.environ.get("AZURE_OPENAI_VISION_DEPLOYMENT"),
    temperature=0
)

# Initialize a BlobServiceClient for storage of images
connect_str = os.environ.get("AZURE_STORAGE") 
blob_service_client = BlobServiceClient.from_connection_string(connect_str)
container_name = 'capstone-images'

# Define the columns
columns = [
    'Alert Type',
    'Ransomware',
    'Victimized Entity', 
    'Hashtagged country', 
    'Entity in image', 
    'Country',
    'Industry'
]

unknown = 'UNK'  # A placeholder string for whenever an error occurred

# Function to upload image to Azure
def upload_to_azure(image_data, image_id):
    img_byte_arr = BytesIO()
    image_data.save(img_byte_arr, format='PNG')
    img_byte_arr = img_byte_arr.getvalue()
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=f"{image_id}.PNG")
    blob_client.upload_blob(img_byte_arr, overwrite=True)
    return blob_client.url
    
# Function to crop and upload image (to reduce chances of triggering Azure OpenAI's content management policy, eg. image containing a human face like graphics
def crop_and_upload_image(url):
    try:
        response = requests.get(url)
        image = Image.open(BytesIO(response.content))
        width, height = image.size
        top = height * 0.60  # Starting from 60% height from the top
        bottom = height - (height * 0.10)  # Ending at 10% height from the bottom
        right = width - (width * 0.40)  # Ending at 40% width from the right
        cropped_image = image.crop((0, top, right, bottom))
        image_id = url.split('/')[-1].rsplit('.', 1)[0]
        image_url = upload_to_azure(cropped_image, image_id)
        return image_url
    except Exception as e:
        print(f"Failed to process or upload image: {e}")
        return None

# Function to read and process tweet
def read_tweet(tweet):
    
    print(f"Analyzing tweet: {tweet[:100]}")
    
    query = f"""
    Read the below cyber security update tweet, and provide an output as instructed. 
    ===TWEET START===
    {tweet}
    ===TWEET END===
    Complete the following tasks:
    If the topic says 'RANSOMEWARE ALERT' or it names a ransomware, give it a classification label: 'Ransomware'; 
    else if the topic says 'DATA BREACH ALERT', give it a classification label: 'Data Breach'.
    Identify the name of the Ransomeware, if applicable.
    Identify the name of the affected organization, if available.
    Identify the country being hashtagged, if available.  
    If for any of the above the information is unknown or not available, state '{unknown}'.
    Provide in JSON format containing the following keys in exact order: {columns[0]}, {columns[1]}, {columns[2]}, {columns[3]},
    with corresponding values being the classification, name of ransomware, affected organization, and hashtagged country.
    """
    response = azure_gpt35turbo.invoke(
        [
            SystemMessage(
                content="You are a cyber security analyst who monitors and analyzes cyber threat trends and data."
            ),
            HumanMessage(content=query),
        ])
    json_content = response.content
    print(json_content)  # For debugging purposes
    return json_content

# Function to analyze image
def analyze_image(url):
    print(f'Analyzing image: {url}')  # For debugging purposes
    if url is None:
        return unknown
    try:
        response = azure_gpt4vision.invoke(
            [
                SystemMessage(
                    content="The provided image likely contains an organization name, a country name and its flag."
                ),
                HumanMessage(
                    content=[
                        {
                            "type": "text", 
                            "text": f"""
                                Identify the organization and country; if it is not a country but a state of the USA, state 'USA'; if it is Taiwan, state 'Taiwan, China'.
                                If for any of the above the information is unknown or not available, state '{unknown}'.
                                """
                        },
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": url,
                                "detail": "auto",
                            },
                        },
                    ]
                )
            ]
        )
        #print(response.content) # For debugging purposes
        response = azure_gpt35turbo.invoke(
            [
                SystemMessage(
                    content="You are a helpful assistant."
                ),
                HumanMessage(content=f"""
                    Reformat the following into JSON format:
                    {response.content}
                """),
            ])
        json_content = response.content
        print(json_content)  # For debugging purposes
        return json_content
    except Exception as e:
        print(f"Error processing image {url}: {e}")
        return unknown  # Return a placeholder string indicating an error occurred

# %% [markdown]
# We make use of agentic AI to automate the classification of the victimized organization into an industry.
#
# Two agents are created.  The first agent **(GPT-3.5-turbo)** will search the web for information on the victim.
#
# The second agent **(GPT-4o)** will receive information gathered by the first agent, and then classify the victim into an industry.
#
# The industry list is from MSCI (there are 25 industry groups) plus an additional 'Government and public services'.

# %%
from crewai import Agent, Task, Crew, Process
from crewai_tools import SerperDevTool
from crewai.tasks.task_output import TaskOutput

search_tool = SerperDevTool()

msci_groups = '''
    'Energy', 
    'Materials', 
    'Capital Goods', 
    'Commercial & Professional Services', 
    'Transportation', 
    'Automobiles & Components', 
    'Consumer Durables & Apparel', 
    'Consumer Services', 
    'Consumer Discretionary Distribution & Retail', 
    'Consumer Staples Distribution & Retail', 
    'Food, Beverage & Tobacco', 
    'Household & Personal Products', 
    'Health Care Equipment & Services', 
    'Pharmaceuticals, Biotechnology & Life Sciences', 
    'Banks', 
    'Financial Services', 
    'Insurance', 
    'Software & Services', 
    'Technology Hardware & Equipment', 
    'Semiconductors & Semiconductor Equipment', 
    'Telecommunication Services', 
    'Media & Entertainment', 
    'Utilities', 
    'Equity Real Estate Investment Trusts (REITs)', 
    'Real Estate Management & Development'
'''

class Tasks:
    def company_search(self, agent, org, country):
        return Task(
            description=f"""
                Given an organization/company named {org} based in {country}, 
                search its exact name on the internet for information to classify its industry.
             """,
            agent=agent,
            #context=context,
            tools=[search_tool], 
            async_execution=False,
            expected_output="""Only a JSON in the following format:
                {
                    "organization": organization,
                    "base country": country,
                    "industry": industry
                }
            """,
        )
    def classification(self, agent, context):
        return Task(
            description=f"""
                Given an orgnaization, its based country and business type, 
                classify it into the one and only one most likely Industry Group strictly from [{msci_groups}, 'Government and public services'].  
                If it is impossible to classify, state the issue and reason.
                """,
            agent=agent,
            context = [context],
            #tools=[search_tool], 
            async_execution=False,
            expected_output="""Only a JSON in the following format:
                {
                    "Industry Group": classification
                }
            """,
        )

def job(company, country):
    print(f'Forming crew to classify industry...')  # For debugging purposes
    # Create agents
    analyst = Agent(
        role="Company Analyst",
        goal="Classify the industry of a given company",
        backstory="""As a junior analyst, your boss gives you an organization/company name and ask you to find out the industry/sector it belongs.  
        You make use of internet search for the task, looking for the most reliable and trusted sources about the company.""",
        tools = [search_tool],
        verbose=False,
        allow_delegation=False,
        max_iter=5,
        llm = azure_gpt35turbo
    )
    
    supervisor = Agent(
        role="Supervisor",
        goal="Classify a non-standard industry name based on a standard Industry Group.",
        backstory=f"""You are a business expert with sound knowledge of all kinds of industries and companies.
        Based on your knowledge, you always classsify a given business type into one and only one strictly among [{msci_groups}, 'Government and public services'].""",
        #tools = [search_tool],
        verbose=False,
        allow_delegation=False,
        max_iter=5,
        llm = azure_gpt4o
    )
    
    # Instantiate the tasks
    tasks = Tasks()
    search = tasks.company_search(analyst, company, country)
    classification = tasks.classification(supervisor, search)
    
    # Form the crew
    crew = Crew(
        agents=[analyst, supervisor],
        tasks=[search,classification],
        process=Process.sequential,
        #manager_llm=ollama,
        verbose=2,
    )
    
    # Kick off the crew's work
    results = crew.kickoff()
    
    # Print the results
    print("Crew Work Results:")
    print(results)
    print()
    return(results)

# %%
# Function to process each row
def process_row(row):
    if row[columns[:6]].isnull().all():
        
        # Process text
        result_json = read_tweet(row['Text'])
        if result_json:
            try:
                result = json.loads(result_json)
                #print(result)  # For debugging purposes
                values = list(result.values())
                for i, col in enumerate(columns[:4]):
                    row[col] = values[i] if i < len(values) else unknown
            except json.JSONDecodeError:
                print("Failed to decode JSON response")
                for i, col in enumerate(columns[:4]):
                    row[col] = unknown
        else:
            print("Response is None or empty")
            for i, col in enumerate(columns[:4]):
                row[col] = unknown

        time.sleep(5)
        
        # Process image
        url = crop_and_upload_image(row['Image'])
        if url:
            try:
                result_json = analyze_image(url)
                if result_json:
                    try:
                        result = json.loads(result_json)
                        #print(result)  # For debugging purposes
                        values = list(result.values())
                        for i, col in enumerate(columns[4:6]):
                            row[col] = values[i] if i < len(values) else unknown
                    except json.JSONDecodeError:
                        print("Failed to decode JSON response")
                        for i, col in enumerate(columns[4:6]):
                            row[col] = unknown
                else:
                    print("Response is None or empty")
                    for i, col in enumerate(columns[4:6]):
                        row[col] = unknown
            except Exception as e:
                print(f"Error processing image {url}: {e}")
                for i, col in enumerate(columns[4:6]):
                    row[col] = unknown

        # Collect organization and country names
        org_names = []
        if row[columns[2]] == row[columns[4]]:
            if row[columns[2]] != unknown:
                org_names.append(row[columns[2]])
        else:
            if row[columns[2]] != unknown:
                org_names.append(row[columns[2]])
            if row[columns[4]] != unknown:
                org_names.append(row[columns[4]])

        country_names = []
        if row[columns[3]] == row[columns[5]]:
            if row[columns[3]] != unknown:
                country_names.append(row[columns[5]])
        else:
            if row[columns[3]] != unknown:
                country_names.append(row[columns[3]])
            if row[columns[5]] != unknown:
                country_names.append(row[columns[5]])

        # Format organization names output
        org_output = f'"{org_names[0]}" or "{org_names[1]}"' if len(org_names) == 2 else org_names[0] if len(org_names) == 1 else 'unknown organization'
        
        # Format country names output
        country_output = f'"{country_names[0]}" or "{country_names[1]}"' if len(country_names) == 2 else country_names[0] if len(country_names) == 1 else 'unknown location'
        
        #print("Organization Names:", org_output)  # For debugging purposes
        #print("Country Names:", country_output)    # For debugging purposes

        time.sleep(5)
        
        try:
            result_json = job(org_output, country_output)
            if result_json:
                try:
                    result = json.loads(result_json)
                    #print(result)  # For debugging purposes
                    values = list(result.values())
                    for i, col in enumerate(columns[6:]):
                        row[col] = values[i] if i < len(values) else unknown
                except json.JSONDecodeError:
                    print("Failed to decode JSON response")
                    for i, col in enumerate(columns[6:]):
                        row[col] = unknown
            else:
                print("Response is None or empty")
                for i, col in enumerate(columns[6:]):
                    row[col] = unknown
        except Exception as e:
            print(f"Error calling job function: {e}")
            for i, col in enumerate(columns[6:]):
                row[col] = unknown


    return row

# %%
import logging

# Process only the first two rows for testing
tweets_update = tweets.apply(process_row, axis=1)

# Display the first few rows of the DataFrame to ensure it's loaded correctly
tweets_update.head()
# Out:
# Analyzing tweet: DATA BREACH ALERT -  Source code of Cyberpunk 2077 allegedly kept for sale  The leaked archive repor
# 01-Jul-24 10:21:53 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Alert Type": "Data Breach",
#   "Ransomware": "UNK",
#   "Victimized Entity": "Cyberpunk 2077",
#   "Hashtagged country": "UNK"
# }
# 01-Jul-24 10:21:59 - Request URL: 'https://karlhku4785985767.blob.core.windows.net/capstone-images/GRKgsu1XEAE52zo.PNG'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '59158'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.10.14 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b21582e8-3750-11ef-bbb9-a83b76af1466'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 01-Jul-24 10:22:00 - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 01 Jul 2024 02:22:02 GMT'
#     'ETag': '"0x8DC997497D7675C"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4c9c44e1-101e-00dc-135d-cbbfa4000000'
#     'x-ms-client-request-id': 'b21582e8-3750-11ef-bbb9-a83b76af1466'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Mon, 01 Jul 2024 02:22:01 GMT'
# Analyzing image: https://karlhku4785985767.blob.core.windows.net/capstone-images/GRKgsu1XEAE52zo.PNG
# 01-Jul-24 10:22:04 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 01-Jul-24 10:22:05 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Organization": "Cyberpunk 2077",
#   "Country": "Poland"
# }
# Forming crew to classify industry...
#  [DEBUG]: == Working Agent: Company Analyst
#  [INFO]: == Starting Task:
#                 Given an organization/company named Cyberpunk 2077 based in Poland,
#                 search its exact name on the internet for information to classify its industry.
#
# 01-Jul-24 10:22:13 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:22:13 - Retrying request to /chat/completions in 2.000000 seconds
# 01-Jul-24 10:22:15 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#
#
#
# Search results: Title: Corporation - Cyberpunk Wiki - Fandom
# Link: https://cyberpunk.fandom.com/wiki/Corporation
# Snippet: Specializing in computer hardware, software, and wetware design, the company was among the main providers of neural processors, microchips, and robotics on the ...
# ---
# Title: Category:Cyberpunk 2077 Corporations
# Link: https://cyberpunk.fandom.com/wiki/Category:Cyberpunk_2077_Corporations
# Snippet: B · Baskin Undercover Inc · BioDyne Systems · Biotech Σ · Biotechnica.
# ---
# Title: Cyberpunk 2077 - Wikipedia
# Link: https://en.wikipedia.org/wiki/Cyberpunk_2077
# Snippet: Cyberpunk 2077 is a 2020 action role-playing video game developed by CD Projekt Red, and published by CD Projekt, and based on Mike Pondsmith's Cyberpunk ...
# ---
# Title: List of Corporations | Cyberpunk 2077 - Game8
# Link: https://game8.co/games/Cyberpunk-2077/archives/321341
# Snippet: List of Corporations · Night Corp · Arasaka Corporation · Militech · Kang Tao · Zetatech · Tsunami Defense Systems · Kiroshi Opticals · Biotechnica.
# ---
# Title: The Corporations of Cyberpunk 2077 - NeoGAF
# Link: https://www.neogaf.com/cyberpunk/corporations.html
# Snippet: It is founded in 2050 by Colonel Shiming Xu, who decides to invest heavily on Research & Development, As a result, Kang Tao builds a reputation for innovative ...
# ---
# Title: The Corporations That Run The Cyberpunk World - YouTube
# Link: https://www.youtube.com/watch?v=h-8b_FV_7ho
# Snippet: Due to the collapse of governments in the Cyberpunk world, Cyberpunk corporations grew to ...
# ---
# Title: CD PROJEKT RED - Award-winning creators of story-driven role ...
# Link: https://www.cdprojektred.com/
# Snippet: Home to over a thousand ambitious individuals. CD PROJEKT RED is a video game development studio focused on storytelling ingenuity, technical innovation, and ...
# ---
# Title: Cyberpunk 2077: The Most Powerful Organizations In The Game ...
# Link: https://gamerant.com/cyberpunk-2077-strongest-organizations-lore/
# Snippet: 1 Arasaka Corporation​​ Most of the equipment, weapons, cyberware enhancements, and other devices used in Night City have Arasaka's name on them. Cyberpunk 2077 ...
# ---
# Title: Lore of the Game - The corporations of the world of Cyberpunk.
# Link: https://www.reddit.com/r/cyberpunkgame/comments/8qv777/lore_of_the_game_the_corporations_of_the_world_of/
# Snippet: Night City gives detailed information on the city that will be the setting for Cyberpunk 2077, and also gives a lot of info on the major gangs.
# ---
# Title: Cyberpunk 2077 - Mega-Corporations! (What Are They?) - YouTube
# Link: https://www.youtube.com/watch?v=nhUtT5Guy3Y
# Snippet: Corporations are giant, multinational companies that dominate the world of Cyberpunk and ...
# ---
#
#
# 01-Jul-24 10:22:18 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:22:18 - Retrying request to /chat/completions in 8.000000 seconds
# 01-Jul-24 10:22:26 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#  [DEBUG]: == [Company Analyst] Task output: {
#     "organization": "Cyberpunk 2077",
#     "base country": "Poland",
#     "industry": "Video Game Development"
# }
#
#
#  [DEBUG]: == Working Agent: Supervisor
#  [INFO]: == Starting Task:
#                 Given an orgnaization, its based country and business type,
#                 classify it into the one and only one most likely Industry Group strictly from [
#     'Energy',
#     'Materials',
#     'Capital Goods',
#     'Commercial & Professional Services',
#     'Transportation',
#     'Automobiles & Components',
#     'Consumer Durables & Apparel',
#     'Consumer Services',
#     'Consumer Discretionary Distribution & Retail',
#     'Consumer Staples Distribution & Retail',
#     'Food, Beverage & Tobacco',
#     'Household & Personal Products',
#     'Health Care Equipment & Services',
#     'Pharmaceuticals, Biotechnology & Life Sciences',
#     'Banks',
#     'Financial Services',
#     'Insurance',
#     'Software & Services',
#     'Technology Hardware & Equipment',
#     'Semiconductors & Semiconductor Equipment',
#     'Telecommunication Services',
#     'Media & Entertainment',
#     'Utilities',
#     'Equity Real Estate Investment Trusts (REITs)',
#     'Real Estate Management & Development'
# , 'Government and public services'].
#                 If it is impossible to classify, state the issue and reason.
#
# 01-Jul-24 10:22:28 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:22:28 - Retrying request to /chat/completions in 0.850573 seconds
# 01-Jul-24 10:22:29 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:22:29 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:22:39 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# Error calling job function: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-03-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Analyzing tweet: RANSOMWARE ALERT ☣ - Federal Reserve Board falls victim to LockBit Ransomware  The group claims to h
# 01-Jul-24 10:22:40 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Alert Type": "Ransomware",
#   "Ransomware": "LockBit",
#   "Victimized Entity": "Federal Reserve Board",
#   "Hashtagged country": "UNK"
# }
# 01-Jul-24 10:22:47 - Request URL: 'https://karlhku4785985767.blob.core.windows.net/capstone-images/GQ1ZOxFXMAAm1yT.PNG'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '63878'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.10.14 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'ce628ede-3750-11ef-a8f8-a83b76af1466'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 01-Jul-24 10:22:47 - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 01 Jul 2024 02:22:48 GMT'
#     'ETag': '"0x8DC9974B3826FA3"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4c9cdc5c-101e-00dc-355d-cbbfa4000000'
#     'x-ms-client-request-id': 'ce628ede-3750-11ef-a8f8-a83b76af1466'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Mon, 01 Jul 2024 02:22:47 GMT'
# Analyzing image: https://karlhku4785985767.blob.core.windows.net/capstone-images/GQ1ZOxFXMAAm1yT.PNG
# 01-Jul-24 10:22:47 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:22:47 - Retrying request to /chat/completions in 14.000000 seconds
# 01-Jul-24 10:23:04 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 01-Jul-24 10:23:05 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Organization": "Federal Reserve Board",
#   "Country": "USA"
# }
# Forming crew to classify industry...
# 01-Jul-24 10:23:10 - Overriding of current TracerProvider is not allowed
#  [DEBUG]: == Working Agent: Company Analyst
#  [INFO]: == Starting Task:
#                 Given an organization/company named Federal Reserve Board based in USA,
#                 search its exact name on the internet for information to classify its industry.
#
# 01-Jul-24 10:23:10 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:23:10 - Retrying request to /chat/completions in 5.000000 seconds
# 01-Jul-24 10:23:16 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#
#
#
# Search results: Title: Federal Reserve Board - Home
# Link: https://www.federalreserve.gov/
# Snippet: The Federal Reserve Board is committed to supporting responsible fintech innovation, both by the firms we regulate directly, and in the financial market broadly ...
# ---
# Title: Federal Reserve Board of Governors - Wikipedia
# Link: https://en.wikipedia.org/wiki/Federal_Reserve_Board_of_Governors
# Snippet: The Board of Governors of the Federal Reserve System, commonly known as the Federal Reserve Board, is the main governing body of the Federal Reserve System.
# ---
# Title: Federal Reserve Board | LinkedIn
# Link: https://www.linkedin.com/company/federal-reserve-board
# Snippet: Supervising and regulating banking institutions to ensure the safety and soundness of the nation's banking and financial system and to protect the credit rights ...
# ---
# Title: Federal Reserve - Wikipedia
# Link: https://en.wikipedia.org/wiki/Federal_Reserve
# Snippet: The Federal Reserve System is composed of several layers. It is governed by the presidentially-appointed board of governors or Federal Reserve Board (FRB).
# ---
# Title: FRBservices.org: The Federal Reserve
# Link: https://www.frbservices.org/
# Snippet: Federal Reserve Bank Services for financial institutions of the United States.
# ---
#
#
# 01-Jul-24 10:23:18 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:23:18 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:23:27 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#  [DEBUG]: == [Company Analyst] Task output: {
#     "organization": "Federal Reserve Board",
#     "base country": "USA",
#     "industry": "Financial Services"
# }
#
#
#  [DEBUG]: == Working Agent: Supervisor
#  [INFO]: == Starting Task:
#                 Given an orgnaization, its based country and business type,
#                 classify it into the one and only one most likely Industry Group strictly from [
#     'Energy',
#     'Materials',
#     'Capital Goods',
#     'Commercial & Professional Services',
#     'Transportation',
#     'Automobiles & Components',
#     'Consumer Durables & Apparel',
#     'Consumer Services',
#     'Consumer Discretionary Distribution & Retail',
#     'Consumer Staples Distribution & Retail',
#     'Food, Beverage & Tobacco',
#     'Household & Personal Products',
#     'Health Care Equipment & Services',
#     'Pharmaceuticals, Biotechnology & Life Sciences',
#     'Banks',
#     'Financial Services',
#     'Insurance',
#     'Software & Services',
#     'Technology Hardware & Equipment',
#     'Semiconductors & Semiconductor Equipment',
#     'Telecommunication Services',
#     'Media & Entertainment',
#     'Utilities',
#     'Equity Real Estate Investment Trusts (REITs)',
#     'Real Estate Management & Development'
# , 'Government and public services'].
#                 If it is impossible to classify, state the issue and reason.
#
# 01-Jul-24 10:23:29 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:23:29 - Retrying request to /chat/completions in 0.899087 seconds
# 01-Jul-24 10:23:30 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:23:30 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:23:40 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# Error calling job function: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-03-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Analyzing tweet: DATA BREACH ALERT - Database of HostLegends allegedly leaked  Threat actor claims to have leaked the
# 01-Jul-24 10:23:41 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Alert Type": "Data Breach",
#   "Ransomware": "UNK",
#   "Victimized Entity": "HostLegends",
#   "Hashtagged country": "UNK"
# }
# 01-Jul-24 10:23:48 - Request URL: 'https://karlhku4785985767.blob.core.windows.net/capstone-images/GQD2qkbXEAERKnL.PNG'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '58880'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.10.14 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'f2f62520-3750-11ef-a8f3-a83b76af1466'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 01-Jul-24 10:23:48 - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 01 Jul 2024 02:23:50 GMT'
#     'ETag': '"0x8DC9974D815CE7B"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4c9d8643-101e-00dc-685d-cbbfa4000000'
#     'x-ms-client-request-id': 'f2f62520-3750-11ef-a8f3-a83b76af1466'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Mon, 01 Jul 2024 02:23:49 GMT'
# Analyzing image: https://karlhku4785985767.blob.core.windows.net/capstone-images/GQD2qkbXEAERKnL.PNG
# 01-Jul-24 10:23:48 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:23:48 - Retrying request to /chat/completions in 13.000000 seconds
# 01-Jul-24 10:24:04 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 01-Jul-24 10:24:05 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Organization": "HOSTLEGENDS",
#   "Country": "USA"
# }
# Forming crew to classify industry...
# 01-Jul-24 10:24:10 - Overriding of current TracerProvider is not allowed
#  [DEBUG]: == Working Agent: Company Analyst
#  [INFO]: == Starting Task:
#                 Given an organization/company named "HostLegends" or "HOSTLEGENDS" based in USA,
#                 search its exact name on the internet for information to classify its industry.
#
# 01-Jul-24 10:24:11 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:24:11 - Retrying request to /chat/completions in 5.000000 seconds
# 01-Jul-24 10:24:16 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#
#
#
# Search results: Title: HostLegends - Unlimited Cloud Hosting | VPS & Dedicated Servers
# Link: https://hostlegends.com/
# Snippet: Get unbeatable hosting solutions at HostLegends. We offer unlimited cloud hosting, powerful VPS hosting, and dedicated servers tailored to meet your needs.
# ---
# Title: Trusted Hosting Provider with Unmatched Expertise - HostLegends
# Link: https://hostlegends.com/about/
# Snippet: HostLegends is a hosting company totally devoted to web and cloud professionals like you. Growing businesses and the Designers, Developers and Agencies who ...
# ---
# Title: Read Customer Service Reviews of hostlegends.com - Trustpilot
# Link: https://www.trustpilot.com/review/hostlegends.com
# Snippet: HostLegends is a SafeShell" Technology Backed Website Hosting Platform To Smoothly Host ... United States. Category. Web Hosting Company. People who looked at ...
# ---
# Title: HostLegends (@hostlegends) • Instagram photos and videos
# Link: https://www.instagram.com/hostlegends/
# Snippet: Web Hosting Solutions for a Connected World. ⚡️ Empower your website with HostLegends Start 30 Days Free Trial using code WELCOME Visit .
# ---
# Title: HostLegends - Facebook
# Link: https://www.facebook.com/hostlegendscom/
# Snippet: HostLegends, San Jose, California. 22 likes · 3 talking about this. Cloud Web Hosting | VPS & Dedicated Servers | Headquartered in California.
# ---
# Title: Contact HostLegends - Reach Out for Support and Inquiries
# Link: https://hostlegends.com/contact/
# Snippet: Support. Aid for resolving issues and achieving goals. Submit Ticket ; Email Us. Use 'Email Us' to quickly seek assistance or make inquiries. support@hostlegends ...
# ---
# Title: Hostlegends Review - YouTube
# Link: https://www.youtube.com/watch?v=c60vZgxD8rU
# Snippet: Get Hostlegends here with my bonuses https://goto.timverdouw.com/hostlegends-youtube ...
# ---
# Title: Hostlegends (@hostlegendscom) / X
# Link: https://twitter.com/hostlegendscom
# Snippet: Hostlegends. @hostlegendscom. Cloud Web Hosting | VPS & Dedicated Servers | Headquartered in California. San Jose, California, US hostlegends.com/shared-hosting ...
# ---
# Title: HostLegends - Instagram
# Link: https://www.instagram.com/hostlegends/p/C8ZUsSlgjv_/
# Snippet: Affordable ways to promote your website. Follow us on social media for more updates #hosting #bhfyp #business #entrepreneur #smallbusiness # ...
# ---
# Title: Bundle | HostLegends
# Link: https://hostlegends.com/funnel/bundle/?aid=1
# Snippet: No hassle, no coding, no amazon AWS keys! works with Amazon's Major Affiliate Programs! United Kingdom, United States, Canada, Germany, France, Spain, Italy ...
# ---
#
#
# 01-Jul-24 10:24:18 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:24:18 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:24:27 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#  [DEBUG]: == [Company Analyst] Task output: {
#     "organization": "HostLegends",
#     "base country": "USA",
#     "industry": "Web Hosting"
# }
#
#
#  [DEBUG]: == Working Agent: Supervisor
#  [INFO]: == Starting Task:
#                 Given an orgnaization, its based country and business type,
#                 classify it into the one and only one most likely Industry Group strictly from [
#     'Energy',
#     'Materials',
#     'Capital Goods',
#     'Commercial & Professional Services',
#     'Transportation',
#     'Automobiles & Components',
#     'Consumer Durables & Apparel',
#     'Consumer Services',
#     'Consumer Discretionary Distribution & Retail',
#     'Consumer Staples Distribution & Retail',
#     'Food, Beverage & Tobacco',
#     'Household & Personal Products',
#     'Health Care Equipment & Services',
#     'Pharmaceuticals, Biotechnology & Life Sciences',
#     'Banks',
#     'Financial Services',
#     'Insurance',
#     'Software & Services',
#     'Technology Hardware & Equipment',
#     'Semiconductors & Semiconductor Equipment',
#     'Telecommunication Services',
#     'Media & Entertainment',
#     'Utilities',
#     'Equity Real Estate Investment Trusts (REITs)',
#     'Real Estate Management & Development'
# , 'Government and public services'].
#                 If it is impossible to classify, state the issue and reason.
#
# 01-Jul-24 10:24:29 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:24:29 - Retrying request to /chat/completions in 0.882422 seconds
# 01-Jul-24 10:24:31 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:24:31 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:24:40 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# Error calling job function: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-03-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Analyzing tweet: RANSOMWARE ALERT - Racal Acoustics Ltd falls victim to RansomHub Ransomware  Group claims to have ac
# 01-Jul-24 10:24:42 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Alert Type": "Ransomware",
#   "Ransomware": "RansomHub Ransomware",
#   "Victimized Entity": "Racal Acoustics Ltd",
#   "Hashtagged country": "UNK"
# }
# 01-Jul-24 10:24:48 - Request URL: 'https://karlhku4785985767.blob.core.windows.net/capstone-images/GP963DtXUAA45UQ.PNG'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '64180'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.10.14 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '16f8aa83-3751-11ef-a457-a83b76af1466'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 01-Jul-24 10:24:49 - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 01 Jul 2024 02:24:50 GMT'
#     'ETag': '"0x8DC9974FC181EA2"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4c9e0d7c-101e-00dc-0f5d-cbbfa4000000'
#     'x-ms-client-request-id': '16f8aa83-3751-11ef-a457-a83b76af1466'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Mon, 01 Jul 2024 02:24:49 GMT'
# Analyzing image: https://karlhku4785985767.blob.core.windows.net/capstone-images/GP963DtXUAA45UQ.PNG
# 01-Jul-24 10:24:49 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:24:49 - Retrying request to /chat/completions in 13.000000 seconds
# 01-Jul-24 10:25:06 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 01-Jul-24 10:25:07 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Organization": "Racal Acoustics Ltd",
#   "Country": "UK"
# }
# Forming crew to classify industry...
# 01-Jul-24 10:25:12 - Overriding of current TracerProvider is not allowed
#  [DEBUG]: == Working Agent: Company Analyst
#  [INFO]: == Starting Task:
#                 Given an organization/company named Racal Acoustics Ltd based in UK,
#                 search its exact name on the internet for information to classify its industry.
#
# 01-Jul-24 10:25:13 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:25:13 - Retrying request to /chat/completions in 5.000000 seconds
# 01-Jul-24 10:25:18 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#
#
#
# Search results: Title: Racal Acoustics | Hearing Protection and Communication Solutions ...
# Link: https://racalacoustics.com/
# Snippet: Providing Situational Awareness Hearing Protection and Communication Solutions. Racal Acoustics solutions include headsets for Land, Sea and Air environments; ...
# ---
# Title: Racal Acoustics Ltd | LinkedIn
# Link: https://www.linkedin.com/company/racal-acoustics-ltd
# Snippet: Racal Acoustics Ltd | 5337 followers on LinkedIn. Providing Situational Awareness Hearing Protection and Communication Solutions.
# ---
# Title: Racal Acoustics | Part of the INVISIO Group
# Link: https://invisio.com/company/about-invisio/the-story-of-racal-acoustics/
# Snippet: More than 100 years of design, development, and manufacture of hearing protection focused headsets for the world's military market.
# ---
# Title: RACAL ACOUSTICS LIMITED overview - Companies House
# Link: https://find-and-update.company-information.service.gov.uk/company/05019038
# Snippet: Registered office address: Waverley Industrial Estate, Hailsham Drive, Harrow, Middlesex, HA1 4TR. Company status: Active. Company type: Private limited ...
# ---
# Title: Racal Acoustics Ltd - Company Profile and News - Bloomberg Markets
# Link: https://www.bloomberg.com/profile/company/319614Z:LN
# Snippet: Racal Acoustics Ltd. designs, manufactures, sells, and supports audio ancillary and field communication equipment. The Company offers noise excluding ...
# ---
# Title: Racal Acoustics - INVISIO
# Link: https://invisio.com/racal-acoustics/
# Snippet: Racal develops and manufactures advanced and robust hearing protection and communication headsets for use in environments with constant high noise. Customers ...
# ---
# Title: Racal Acoustics - Crunchbase Company Profile & Funding
# Link: https://www.crunchbase.com/organization/racal-acoustics
# Snippet: Racal Acoustics Limited designs, manufactures, sells, and supports audio ancillary and field communication equipment for military environments.
# ---
#
#
# 01-Jul-24 10:25:20 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:25:20 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:25:30 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#  [DEBUG]: == [Company Analyst] Task output: {
#     "organization": "Racal Acoustics Ltd",
#     "base country": "UK",
#     "industry": "Hearing Protection and Communication Solutions"
# }
#
#
#  [DEBUG]: == Working Agent: Supervisor
#  [INFO]: == Starting Task:
#                 Given an orgnaization, its based country and business type,
#                 classify it into the one and only one most likely Industry Group strictly from [
#     'Energy',
#     'Materials',
#     'Capital Goods',
#     'Commercial & Professional Services',
#     'Transportation',
#     'Automobiles & Components',
#     'Consumer Durables & Apparel',
#     'Consumer Services',
#     'Consumer Discretionary Distribution & Retail',
#     'Consumer Staples Distribution & Retail',
#     'Food, Beverage & Tobacco',
#     'Household & Personal Products',
#     'Health Care Equipment & Services',
#     'Pharmaceuticals, Biotechnology & Life Sciences',
#     'Banks',
#     'Financial Services',
#     'Insurance',
#     'Software & Services',
#     'Technology Hardware & Equipment',
#     'Semiconductors & Semiconductor Equipment',
#     'Telecommunication Services',
#     'Media & Entertainment',
#     'Utilities',
#     'Equity Real Estate Investment Trusts (REITs)',
#     'Real Estate Management & Development'
# , 'Government and public services'].
#                 If it is impossible to classify, state the issue and reason.
#
# 01-Jul-24 10:25:31 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:25:31 - Retrying request to /chat/completions in 0.897368 seconds
# 01-Jul-24 10:25:33 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:25:33 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:25:43 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# Error calling job function: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-03-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Analyzing tweet: RANSOMWARE ALERT - Smartweb falls victim to PLAY Ransomware  Group claims to publish the organizatio
# 01-Jul-24 10:25:44 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Alert Type": "Ransomware",
#   "Ransomware": "PLAY Ransomware",
#   "Victimized Entity": "Smartweb",
#   "Hashtagged country": "UNK"
# }
# 01-Jul-24 10:25:50 - Request URL: 'https://karlhku4785985767.blob.core.windows.net/capstone-images/GP7_fFzXcAAH7WJ.PNG'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '57732'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.10.14 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '3bed0802-3751-11ef-a363-a83b76af1466'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 01-Jul-24 10:25:51 - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 01 Jul 2024 02:25:52 GMT'
#     'ETag': '"0x8DC9975210C4A1A"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4c9ea446-101e-00dc-555d-cbbfa4000000'
#     'x-ms-client-request-id': '3bed0802-3751-11ef-a363-a83b76af1466'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Mon, 01 Jul 2024 02:25:51 GMT'
# Analyzing image: https://karlhku4785985767.blob.core.windows.net/capstone-images/GP7_fFzXcAAH7WJ.PNG
# 01-Jul-24 10:25:51 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:25:51 - Retrying request to /chat/completions in 12.000000 seconds
# 01-Jul-24 10:26:07 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 01-Jul-24 10:26:08 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Organization": "SMARTWEB",
#   "Country": "USA"
# }
# Forming crew to classify industry...
# 01-Jul-24 10:26:13 - Overriding of current TracerProvider is not allowed
#  [DEBUG]: == Working Agent: Company Analyst
#  [INFO]: == Starting Task:
#                 Given an organization/company named "Smartweb" or "SMARTWEB" based in USA,
#                 search its exact name on the internet for information to classify its industry.
#
# 01-Jul-24 10:26:13 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:26:13 - Retrying request to /chat/completions in 5.000000 seconds
# 01-Jul-24 10:26:19 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#
#
#
# Search results: Title: Smartweb Inc. - LinkedIn
# Link: https://www.linkedin.com/company/smartweb-inc-
# Snippet: About us. New York City based company, Smartweb, Inc. has for over 20 years provided “mission critical” systems to various Fortune 500 companies, ...
# ---
# Title: Smartwebs | Community Association Management Software
# Link: https://smartwebs.com/
# Snippet: All-in-one cloud-based Community Association Management Software to automate your community association. Collect dues, communications & more.
# ---
# Title: SmartWeb Corp
# Link: https://smartwebusa.com/
# Snippet: SmartWeb is a Managed Service Provider that specializes in cybersecurity for accounting and tax firms.
# ---
# Title: Welcome to Smartweb 2.0
# Link: https://smartweb2.smartstartinc.com/index.xhtml?sessionExpired=true
# Snippet: Welcome to Smartweb 2.0 · Already Registered? Username Sign In · Register Now Email Start Registration · Forgot your Username or Password? Email Send Reminder.
# ---
# Title: Smart Web Design & Ecommerce – WordPress Website ...
# Link: https://smartwebdesigns.us/
# Snippet: Let Smart Web Design & Ecommerce be your guide through the various approaches available and ensure you get a comprehensive strategy that delivers results.
# ---
# Title: Applied SmartWeb
# Link: https://www.appliedmaterials.com/us/en/product-library/applied-smartweb.html
# Snippet: Roll-to-roll sputter coating system for flexible electronics and optical multilayers. Complete scalability from R&D to production; Web widths from 400mm ...
# ---
# Title: SmartWeb Marketing: Ready To Grow Your Business?
# Link: https://getsmartwebmarketing.com/
# Snippet: Digital Advertising Agency USA. Navigation Menu. Search for... Navigation Menu ... SmartWeb Marketing has helped a business just like yours and has a ready ...
# ---
# Title: SmartWeb Worldwide: Web Design and Digital Marketing Studio in ...
# Link: https://smartweb.moscow/
# Snippet: We work with B2B and B2C customers accross the United States of America. Web design and SEO for US companies in: Alabama; Alaska; Arizona; Arkansas; California ...
# ---
# Title: Contact Us – SmartWeb – Software Company
# Link: https://smartweb.me/contact/
# Snippet: SmartWeb is a leading web development agency. We are specialists in custom-made developments. Our group of experts is smart and committed to ...
# ---
# Title: HOA Management Software Pricing - Smartwebs
# Link: https://smartwebs.com/pricing/
# Snippet: Quick comparison of some of our main features. ; Unlimited Users ; Unlimited Storage ; U.S. Based Support via email and phone ; Resident & Board Portals.
# ---
#
#
# 01-Jul-24 10:26:21 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:26:21 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:26:30 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#  [DEBUG]: == [Company Analyst] Task output: {
#     "organization": "Smartweb",
#     "base country": "USA",
#     "industry": "Information Technology"
# }
#
#
#  [DEBUG]: == Working Agent: Supervisor
#  [INFO]: == Starting Task:
#                 Given an orgnaization, its based country and business type,
#                 classify it into the one and only one most likely Industry Group strictly from [
#     'Energy',
#     'Materials',
#     'Capital Goods',
#     'Commercial & Professional Services',
#     'Transportation',
#     'Automobiles & Components',
#     'Consumer Durables & Apparel',
#     'Consumer Services',
#     'Consumer Discretionary Distribution & Retail',
#     'Consumer Staples Distribution & Retail',
#     'Food, Beverage & Tobacco',
#     'Household & Personal Products',
#     'Health Care Equipment & Services',
#     'Pharmaceuticals, Biotechnology & Life Sciences',
#     'Banks',
#     'Financial Services',
#     'Insurance',
#     'Software & Services',
#     'Technology Hardware & Equipment',
#     'Semiconductors & Semiconductor Equipment',
#     'Telecommunication Services',
#     'Media & Entertainment',
#     'Utilities',
#     'Equity Real Estate Investment Trusts (REITs)',
#     'Real Estate Management & Development'
# , 'Government and public services'].
#                 If it is impossible to classify, state the issue and reason.
#
# 01-Jul-24 10:26:32 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:26:32 - Retrying request to /chat/completions in 0.926490 seconds
# 01-Jul-24 10:26:34 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:26:34 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:26:43 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# Error calling job function: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-03-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Analyzing tweet: DATA BREACH ALERT - Opensoft database allegedly leaked  A threat actor claims to have breached OpenS
# 01-Jul-24 10:26:45 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Alert Type": "Data Breach",
#   "Ransomware": "UNK",
#   "Victimized Entity": "OpenSoft",
#   "Hashtagged country": "UNK"
# }
# 01-Jul-24 10:26:51 - Request URL: 'https://karlhku4785985767.blob.core.windows.net/capstone-images/GPtBqcGWsAAX1yv.PNG'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '59496'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.10.14 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '60012540-3751-11ef-b063-a83b76af1466'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 01-Jul-24 10:26:51 - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Mon, 01 Jul 2024 02:26:52 GMT'
#     'ETag': '"0x8DC99754520102F"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4c9f102a-101e-00dc-535e-cbbfa4000000'
#     'x-ms-client-request-id': '60012540-3751-11ef-b063-a83b76af1466'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Mon, 01 Jul 2024 02:26:52 GMT'
# Analyzing image: https://karlhku4785985767.blob.core.windows.net/capstone-images/GPtBqcGWsAAX1yv.PNG
# 01-Jul-24 10:26:51 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:26:51 - Retrying request to /chat/completions in 12.000000 seconds
# 01-Jul-24 10:27:06 - HTTP Request: POST https://karlgptvision.openai.azure.com//openai/deployments/gpt4vision/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 01-Jul-24 10:27:07 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# {
#   "Organization": "OPENSOF",
#   "Country": "Portugal"
# }
# Forming crew to classify industry...
# 01-Jul-24 10:27:12 - Overriding of current TracerProvider is not allowed
#  [DEBUG]: == Working Agent: Company Analyst
#  [INFO]: == Starting Task:
#                 Given an organization/company named "OpenSoft" or "OPENSOF" based in Portugal,
#                 search its exact name on the internet for information to classify its industry.
#
# 01-Jul-24 10:27:12 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:27:12 - Retrying request to /chat/completions in 5.000000 seconds
# 01-Jul-24 10:27:18 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#
#
#
# Search results: Title: Opensoft: Home
# Link: https://www.opensoft.pt/
# Snippet: ... de todos. Junta-te a nós! Email: comercial@opensoft.pt. Tel: +351 21 380 44 10. Home · Software · Consultoria · Nearshoring · Digitalização de serviços ...
# ---
# Title: Opensoft
# Link: https://www.opensoft.pt/en/
# Snippet: Custom tech solutions that drive the growth of your organisation. Software development, technology consulting, and nearshoring.
# ---
# Title: Working at Opensoft (Portugal) - Glassdoor
# Link: https://www.glassdoor.com/Overview/Working-at-Opensoft-Portugal-EI_IE782837.11,28.htm
# Snippet: Opensoft is a Portuguese company formed by highly qualified software engineers. We like to be challenged and to work on projects that create a positive ...
# ---
# Title: Opensoft - OpenCms
# Link: http://www.opencms.org/en/modules/solution_providers/partner_00185.html
# Snippet: Opensoft is a Portuguese IT company specialized in consultancy, implementation and support of technological solutions. One of its main areas of intervention ...
# ---
# Title: Opensoft (Portugal) Reviews: What Is It Like to Work At ... - Glassdoor
# Link: https://www.glassdoor.com/Reviews/Opensoft-Portugal-Reviews-E782837.htm
# Snippet: Opensoft (Portugal) has an overall rating of 3.1 out of 5, based on over 24 reviews left anonymously by employees. 50% of employees would recommend working at ...
# ---
# Title: Opensoft — Consulting Organization from Portugal, experience with ...
# Link: https://www.developmentaid.org/organizations/view/279270/opensoft
# Snippet: Opensoft is a Portuguese tech company specialized in software engineering and technological consultancy. We help our customers in their digital ...
# ---
# Title: Opensoft | Lisbon - Facebook
# Link: https://www.facebook.com/OpensoftSA/
# Snippet: Opensoft, Lisbon, Portugal. 2323 likes · 9 talking about this · 13 were here. A Opensoft é uma empresa portuguesa de engenheiros de software altamente...
# ---
# Title: Opensoft - LinkedIn
# Link: https://www.linkedin.com/company/opensoft_2
# Snippet: Opensoft is a custom software development company with extensive experience in building custom e-commerce solutions, industrial automation systems, ...
# ---
# Title: Opensoft - Crunchbase Company Profile & Funding
# Link: https://www.crunchbase.com/organization/opensoft
# Snippet: Where is Opensoft 's headquarters? Opensoft is located in Lisbon, Lisboa, Portugal . Who are Opensoft 's competitors? Alternatives and possible competitors ...
# ---
# Title: OPENSOFT - SGPS - R. Coronel Figueiredo, 1, 2º, Silves, Portugal
# Link: https://m.yelp.com/biz/opensoft-sgps-silves
# Snippet: R. Coronel Figueiredo, 1, 2º. 8300-000 Silves. Portugal. Directions. Is this your business? Respond to reviews and customer messages.
# ---
#
#
# 01-Jul-24 10:27:20 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:27:20 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:27:29 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt35turbo/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
#  [DEBUG]: == [Company Analyst] Task output: {
#     "organization": "OpenSoft",
#     "base country": "Portugal",
#     "industry": "Software Development/Technology Consulting"
# }
#
#
#  [DEBUG]: == Working Agent: Supervisor
#  [INFO]: == Starting Task:
#                 Given an orgnaization, its based country and business type,
#                 classify it into the one and only one most likely Industry Group strictly from [
#     'Energy',
#     'Materials',
#     'Capital Goods',
#     'Commercial & Professional Services',
#     'Transportation',
#     'Automobiles & Components',
#     'Consumer Durables & Apparel',
#     'Consumer Services',
#     'Consumer Discretionary Distribution & Retail',
#     'Consumer Staples Distribution & Retail',
#     'Food, Beverage & Tobacco',
#     'Household & Personal Products',
#     'Health Care Equipment & Services',
#     'Pharmaceuticals, Biotechnology & Life Sciences',
#     'Banks',
#     'Financial Services',
#     'Insurance',
#     'Software & Services',
#     'Technology Hardware & Equipment',
#     'Semiconductors & Semiconductor Equipment',
#     'Telecommunication Services',
#     'Media & Entertainment',
#     'Utilities',
#     'Equity Real Estate Investment Trusts (REITs)',
#     'Real Estate Management & Development'
# , 'Government and public services'].
#                 If it is impossible to classify, state the issue and reason.
#
# 01-Jul-24 10:27:31 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:27:31 - Retrying request to /chat/completions in 0.765805 seconds
# 01-Jul-24 10:27:32 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:27:32 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:27:42 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# Error calling job function: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-03-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
#                  Date (UTC)  \
# 0 2024-06-28 13:37:00+00:00
# 1 2024-06-24 11:12:00+00:00
# 0 2024-06-14 20:19:00+00:00
# 1 2024-06-13 16:40:00+00:00
# 2 2024-06-13 07:41:00+00:00
#
#                                                  URL  \
# 0  https://twitter.com/dexpose_io/status/18066834...
# 1  https://twitter.com/dexpose_io/status/18051973...
# 0  https://twitter.com/dexpose_io/status/18017111...
# 1  https://twitter.com/dexpose_io/status/18012935...
# 2  https://twitter.com/dexpose_io/status/18011579...
#
#                                              Image  \
# 0  https://pbs.twimg.com/media/GRKgsu1XEAE52zo.jpg
# 1  https://pbs.twimg.com/media/GQ1ZOxFXMAAm1yT.jpg
# 0  https://pbs.twimg.com/media/GQD2qkbXEAERKnL.jpg
# 1  https://pbs.twimg.com/media/GP963DtXUAA45UQ.jpg
# 2  https://pbs.twimg.com/media/GP7_fFzXcAAH7WJ.jpg
#
#                                                 Text  \
# 0  DATA BREACH ALERT -  Source code of Cyberpunk ...
# 1  RANSOMWARE ALERT ☣ - Federal Reserve Board fal...
# 0  DATA BREACH ALERT - Database of HostLegends al...
# 1  RANSOMWARE ALERT - Racal Acoustics Ltd falls v...
# 2  RANSOMWARE ALERT - Smartweb falls victim to PL...
#
#                  Scrape Date   Alert Type            Ransomware  \
# 0  2024-07-01 10:20:36+00:00  Data Breach                   UNK
# 1  2024-07-01 10:20:36+00:00   Ransomware               LockBit
# 0  2024-06-19 21:26:50+00:00  Data Breach                   UNK
# 1  2024-06-19 21:26:50+00:00   Ransomware  RansomHub Ransomware
# 2  2024-06-19 21:26:50+00:00   Ransomware       PLAY Ransomware
#
#        Victimized Entity Hashtagged country        Entity in image Country  \
# 0         Cyberpunk 2077                UNK         Cyberpunk 2077  Poland
# 1  Federal Reserve Board                UNK  Federal Reserve Board     USA
# 0            HostLegends                UNK            HOSTLEGENDS     USA
# 1    Racal Acoustics Ltd                UNK    Racal Acoustics Ltd      UK
# 2               Smartweb                UNK               SMARTWEB     USA
#
#   Industry
# 0      UNK
# 1      UNK
# 0      UNK
# 1      UNK
# 2      UNK

# %%
# Merging updates to existing file
tweets.update(tweets_update)

# Save the updated file
tweets.to_csv(f'{username}.csv', index=False, encoding='utf-8')

# %% [markdown]
# With the tweets information already saved in a csv file, we can now employ an agent powered by **GPT-4** to analyze the csv data.
#
# This allows us to automate the querying of the csv data.

# %%
from langchain_experimental.agents.agent_toolkits import create_csv_agent, create_pandas_dataframe_agent
from langchain.agents.agent_types import AgentType

csv_agent = create_csv_agent(
    azure_gpt4o,
    f"{username}.csv",
    verbose=False,
    agent_type=AgentType.OPENAI_FUNCTIONS,
)

def tweets_stats(queries):
    prompt = f'''You are given a dataset of historic cyber security alerts.
        'Date (UTC)' column is the alert publish date.
        'URL' column is the url to the alert.
        'Image' column is the url to the alert image.	
        'Text' column is the text content of the alert.	
        '{columns[0]}' column shows the type of alert given by the alert.
        '{columns[1]}' column shows the name of ransomware mentioned by the alert.	
        '{columns[2]}' gives the name of the victimized organization mentioned in the alert.
        '{columns[5]}' gives the country in which the victimized organization is based.
        '{columns[6]}' gives the industry of the victimized organization.
        Answer the question by appropriately analyzing the data, but ignoring columns '{columns[3]}' and '{columns[4]}' and 'UNK' values. '''
    responses = []
    for query in queries:
        response = csv_agent.invoke(
            [
                SystemMessage(content=prompt),
                HumanMessage(content=query),
            ])
        responses.append(response['output'])
    return responses

# %%
q1 = "How many alerts were published in Q1 2024?"
q2 = "Looking at only Ransomware Alert, what are the top 3 ransomwares in Q1 2024?"
q3 = "What are the top 3 countries where victims of Ransomware are based in Q1 2024?"
q4 = "What are the top 3 countries where victims of Data Breach are based in Q1 2024?"

queries = [q1, q2, q3, q4]

responses = tweets_stats(queries)

for response in responses:
    print(response)
# Out:
# 01-Jul-24 10:49:32 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:49:32 - Retrying request to /chat/completions in 0.983072 seconds
# 01-Jul-24 10:49:33 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 01-Jul-24 10:49:33 - Retrying request to /chat/completions in 9.000000 seconds
# 01-Jul-24 10:49:43 - HTTP Request: POST https://karlchatgpt-east-us.openai.azure.com//openai/deployments/gpt4o/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[12], line 8
#       4 q4 = "What are the top 3 countries where victims of Data Breach are based in Q1 2024?"
#       6 queries = [q1, q2, q3, q4]
# ----> 8 responses = tweets_stats(queries)
#      10 for response in responses:
#      11     print(response)
#
# Cell In[11], line 25, in tweets_stats(queries)
#      23 responses = []
#      24 for query in queries:
# ---> 25     response = csv_agent.invoke(
#      26         [
#      27             SystemMessage(content=prompt),
#      28             HumanMessage(content=query),
#      29         ])
#      30     responses.append(response['output'])
#      31 return responses
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain\chains\base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain\chains\base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# --> 153         self._call(inputs, run_manager=run_manager)
#     154         if new_arg_supported
#     155         else self._call(inputs)
#     156     )
#     158     final_outputs: Dict[str, Any] = self.prep_outputs(
#     159         inputs, outputs, return_only_outputs
#     160     )
#     161 except BaseException as e:
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain\agents\agent.py:1432, in AgentExecutor._call(self, inputs, run_manager)
#    1430 # We now enter the agent loop (until it returns something).
#    1431 while self._should_continue(iterations, time_elapsed):
# -> 1432     next_step_output = self._take_next_step(
#    1433         name_to_tool_map,
#    1434         color_mapping,
#    1435         inputs,
#    1436         intermediate_steps,
#    1437         run_manager=run_manager,
#    1438     )
#    1439     if isinstance(next_step_output, AgentFinish):
#    1440         return self._return(
#    1441             next_step_output, intermediate_steps, run_manager=run_manager
#    1442         )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain\agents\agent.py:1138, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1129 def _take_next_step(
#    1130     self,
#    1131     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1135     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1136 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1137     return self._consume_next_step(
# -> 1138         [
#    1139             a
#    1140             for a in self._iter_next_step(
#    1141                 name_to_tool_map,
#    1142                 color_mapping,
#    1143                 inputs,
#    1144                 intermediate_steps,
#    1145                 run_manager,
#    1146             )
#    1147         ]
#    1148     )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain\agents\agent.py:1138, in <listcomp>(.0)
#    1129 def _take_next_step(
#    1130     self,
#    1131     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1135     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1136 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1137     return self._consume_next_step(
# -> 1138         [
#    1139             a
#    1140             for a in self._iter_next_step(
#    1141                 name_to_tool_map,
#    1142                 color_mapping,
#    1143                 inputs,
#    1144                 intermediate_steps,
#    1145                 run_manager,
#    1146             )
#    1147         ]
#    1148     )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain\agents\agent.py:1166, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1163     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1165     # Call the LLM to see what to do.
# -> 1166     output = self.agent.plan(
#    1167         intermediate_steps,
#    1168         callbacks=run_manager.get_child() if run_manager else None,
#    1169         **inputs,
#    1170     )
#    1171 except OutputParserException as e:
#    1172     if isinstance(self.handle_parsing_errors, bool):
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain\agents\openai_functions_agent\base.py:100, in OpenAIFunctionsAgent.plan(self, intermediate_steps, callbacks, with_functions, **kwargs)
#      98 messages = prompt.to_messages()
#      99 if with_functions:
# --> 100     predicted_message = self.llm.predict_messages(
#     101         messages,
#     102         functions=self.functions,
#     103         callbacks=callbacks,
#     104     )
#     105 else:
#     106     predicted_message = self.llm.predict_messages(
#     107         messages,
#     108         callbacks=callbacks,
#     109     )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain_core\_api\deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain_core\language_models\chat_models.py:864, in BaseChatModel.predict_messages(self, messages, stop, **kwargs)
#     862 else:
#     863     _stop = list(stop)
# --> 864 return self(messages, stop=_stop, **kwargs)
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain_core\_api\deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain_core\language_models\chat_models.py:808, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     800 @deprecated("0.1.7", alternative="invoke", removal="0.3.0")
#     801 def __call__(
#     802     self,
#    (...)
#     806     **kwargs: Any,
#     807 ) -> BaseMessage:
# --> 808     generation = self.generate(
#     809         [messages], stop=stop, callbacks=callbacks, **kwargs
#     810     ).generations[0][0]
#     811     if isinstance(generation, ChatGeneration):
#     812         return generation.message
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain_core\language_models\chat_models.py:421, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     419         if run_managers:
#     420             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 421         raise e
#     422 flattened_outputs = [
#     423     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     424     for res in results
#     425 ]
#     426 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain_core\language_models\chat_models.py:411, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     408 for i, m in enumerate(messages):
#     409     try:
#     410         results.append(
# --> 411             self._generate_with_cache(
#     412                 m,
#     413                 stop=stop,
#     414                 run_manager=run_managers[i] if run_managers else None,
#     415                 **kwargs,
#     416             )
#     417         )
#     418     except BaseException as e:
#     419         if run_managers:
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain_core\language_models\chat_models.py:632, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     630 else:
#     631     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 632         result = self._generate(
#     633             messages, stop=stop, run_manager=run_manager, **kwargs
#     634         )
#     635     else:
#     636         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\capstone\lib\site-packages\langchain_openai\chat_models\base.py:451, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     445 message_dicts, params = self._create_message_dicts(messages, stop)
#     446 params = {
#     447     **params,
#     448     **({"stream": stream} if stream is not None else {}),
#     449     **kwargs,
#     450 }
# --> 451 response = self.client.create(messages=message_dicts, **params)
#     452 return self._create_chat_result(response)
#
# File ~\anaconda3\envs\capstone\lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\capstone\lib\site-packages\openai\resources\chat\completions.py:590, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     558 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     559 def create(
#     560     self,
#    (...)
#     588     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     589 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 590     return self._post(
#     591         "/chat/completions",
#     592         body=maybe_transform(
#     593             {
#     594                 "messages": messages,
#     595                 "model": model,
#     596                 "frequency_penalty": frequency_penalty,
#     597                 "function_call": function_call,
#     598                 "functions": functions,
#     599                 "logit_bias": logit_bias,
#     600                 "logprobs": logprobs,
#     601                 "max_tokens": max_tokens,
#     602                 "n": n,
#     603                 "presence_penalty": presence_penalty,
#     604                 "response_format": response_format,
#     605                 "seed": seed,
#     606                 "stop": stop,
#     607                 "stream": stream,
#     608                 "stream_options": stream_options,
#     609                 "temperature": temperature,
#     610                 "tool_choice": tool_choice,
#     611                 "tools": tools,
#     612                 "top_logprobs": top_logprobs,
#     613                 "top_p": top_p,
#     614                 "user": user,
#     615             },
#     616             completion_create_params.CompletionCreateParams,
#     617         ),
#     618         options=make_request_options(
#     619             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     620         ),
#     621         cast_to=ChatCompletion,
#     622         stream=stream or False,
#     623         stream_cls=Stream[ChatCompletionChunk],
#     624     )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\openai\_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\capstone\lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\openai\_base_client.py:1005, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1003 if retries > 0 and self._should_retry(err.response):
#    1004     err.response.close()
# -> 1005     return self._retry_request(
#    1006         options,
#    1007         cast_to,
#    1008         retries,
#    1009         err.response.headers,
#    1010         stream=stream,
#    1011         stream_cls=stream_cls,
#    1012     )
#    1014 # If the response is streamed then we need to explicitly read the response
#    1015 # to completion before attempting to access the response text.
#    1016 if not err.response.is_closed:
#
# File ~\anaconda3\envs\capstone\lib\site-packages\openai\_base_client.py:1053, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1049 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1050 # different thread if necessary.
#    1051 time.sleep(timeout)
# -> 1053 return self._request(
#    1054     options=options,
#    1055     cast_to=cast_to,
#    1056     remaining_retries=remaining,
#    1057     stream=stream,
#    1058     stream_cls=stream_cls,
#    1059 )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\openai\_base_client.py:1005, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1003 if retries > 0 and self._should_retry(err.response):
#    1004     err.response.close()
# -> 1005     return self._retry_request(
#    1006         options,
#    1007         cast_to,
#    1008         retries,
#    1009         err.response.headers,
#    1010         stream=stream,
#    1011         stream_cls=stream_cls,
#    1012     )
#    1014 # If the response is streamed then we need to explicitly read the response
#    1015 # to completion before attempting to access the response text.
#    1016 if not err.response.is_closed:
#
# File ~\anaconda3\envs\capstone\lib\site-packages\openai\_base_client.py:1053, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1049 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1050 # different thread if necessary.
#    1051 time.sleep(timeout)
# -> 1053 return self._request(
#    1054     options=options,
#    1055     cast_to=cast_to,
#    1056     remaining_retries=remaining,
#    1057     stream=stream,
#    1058     stream_cls=stream_cls,
#    1059 )
#
# File ~\anaconda3\envs\capstone\lib\site-packages\openai\_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1027     stream_cls=stream_cls,
#    1028 )
#
# RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the ChatCompletions_Create Operation under Azure OpenAI API version 2024-03-01-preview have exceeded token rate limit of your current OpenAI S0 pricing tier. Please retry after 86400 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}

# %%
q5 = "How many times did China become the subject of Ransomware attack in 2024?"
q6 = "How many times did China become the subject of Data Breach incident in 2024?"
q7 = "In 2024, which are the top 3 industries that have become the victims of Ransomware attack?"
q8 = "In 2024, which are the top 3 industries that have become the victims of Data Breach incident?"

queries = [q5, q6, q7, q8]

responses = tweets_stats(queries)

for response in responses:
    print(response)
# Out:
# 27-May-24 23:23:36 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:23:40 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:23:40 - Retrying request to /chat/completions in 5.000000 seconds
# 27-May-24 23:23:45 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:23:49 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:23:49 - Retrying request to /chat/completions in 7.000000 seconds
# 27-May-24 23:23:57 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:24:00 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:24:00 - Retrying request to /chat/completions in 7.000000 seconds
# 27-May-24 23:24:08 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:24:09 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:24:09 - Retrying request to /chat/completions in 9.000000 seconds
# 27-May-24 23:24:20 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:24:25 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:24:25 - Retrying request to /chat/completions in 4.000000 seconds
# 27-May-24 23:24:30 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:24:31 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:24:31 - Retrying request to /chat/completions in 9.000000 seconds
# 27-May-24 23:24:42 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:24:46 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:24:46 - Retrying request to /chat/completions in 5.000000 seconds
# 27-May-24 23:24:52 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:25:02 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:25:02 - Retrying request to /chat/completions in 1.000000 seconds
# 27-May-24 23:25:04 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:25:08 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:25:08 - Retrying request to /chat/completions in 5.000000 seconds
# 27-May-24 23:25:15 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# 27-May-24 23:25:17 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 429 Too Many Requests"
# 27-May-24 23:25:17 - Retrying request to /chat/completions in 7.000000 seconds
# 27-May-24 23:25:25 - HTTP Request: POST https://karlopenai.openai.azure.com//openai/deployments/gpt4/chat/completions?api-version=2024-03-01-preview "HTTP/1.1 200 OK"
# China became the subject of a Ransomware attack 2 times in 2024.
# China became the subject of a Data Breach incident 2 times in 2024.
# In 2024, the top 3 industries that have become the victims of Ransomware attacks are:
#
# 1. Commercial & Professional Services with 33 attacks
# 2. Capital Goods with 22 attacks
# 3. Software & Services with 14 attacks
# In 2024, the top 3 industries that have become the victims of Data Breach incidents are:
#
# 1. Commercial & Professional Services with 15 incidents
# 2. Software & Services with 12 incidents
# 3. Financial Services with 9 incidents
